# %%
# conditional logic

# ==, >, >=< <, <=, !=

a = 7 
b = 10

print(a==b)
# Out:
# False

# %%
num_chances = 2
our_chance = input("please enter a number: ")
our_chance = int(our_chance)
print(f"user chose {our_chance}")
print(our_chance > num_chances)
# Out:
# user chose 3
# True

# %%
# not equal

a = False
print(a!=True)
# Out:
# True

# %%
# Truthy & Falsy
a = 7 
print(bool(a))
# Out:
# True

# %%
# Falsy
# 0, 0.0, false, none, [], {}, (), ""
my_list = []
print(bool(my_list))
# Out:
# False

# %%
# if statements

condition = ""
if condition: 
    #pass # does nothing let's me continue logic without error
    print(f"condition is true")
elif not condition:
    #pass
    print("condition is false")
else: 
    print("i got the else statement")
    
print(f"not statement = {not condition}")
# Out:
# condition is false
# not statement = True

# %%
num = input ("please enter a number")

if num < 3:
    print(f"num is less lthan 3: {num}")
elif num > 6:
    print(f"nume is greater than 6: {num}")
else: 
    print(f"num is between 3 and 6")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 3
#       1 num = input ("please enter a number")
# ----> 3 if num < 3:
#       4     print(f"num is less lthan 3: {num}")
#       5 elif num > 6:
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
# let's make this better with tryy except

num = input("choose a number between 1 and 10")

try:
    num = int(num)
if num < 3:
    print(f"num is less lthan 3: {num}")
elif num > 6:
    print(f"nume is greater than 6: {num}")
else: 
    print(f"num is between 3 and 6")
    
except Exception as e:
    print(f"well that didnt work try again, try again: {e}")
# Out:
#   Cell In[32], line 5
#     try
#        ^
# SyntaxError: expected ':'

# %%
# type hinting: str, float, int, book=l
# Nested IF statements
variable: str = input(f"please, enter a value")

if variable.isnumeric():
    try:
        num = float(variable)
        if num > 10:
            print("the value is too high, start over")
        else:
            print(f"{num} is good choice")
    except Exception as e:
        print(f"there was an error: {e}")
elif variable.isalpha():
    print(f"you chose, {variable.upper()}")
else:
    print("please enter either a number or a leetter")
# Out:
# 1.0 is good choice

# %%
number = input("choose a number between 1 and 10!")

# and statement
if number.isnumeric():
    try:
        number = int(number)
        if number >= 1 and number <= 10:
            print(f"you chose correctly: {number}")
        else:
            print(f"you suck! {number} is not between 1 and 10")
    except Exception as e:
        print(e)
    number = int(number)
else:
    print("please choose a number")
# Out:
# you suck! 99 is not between 1 and 10

# %%
# want a number not between 1 and 10 or -10 and -1

number = input("please choose a number between -10 and -1 or 1 and 10")

try:
    if not number.isnumeric(): 
        raise Exception(f"{number} is not a number buster, try reading!")
    
    number = int(number)
    if (number < -10 or number > -1) or (number < 1 or number > 10): 
        raise Exception(f"{number} doesn't meet the rules, pay attention")
    
    print(f"Hooray!, you made it through: {number} meets the rules. Sorry if you chose a negative number, but '-' is not numeric")                    
except Exception as e: 
    print(f"there was an error: {e}")
# Out:
# there was an error: 9 doesn't meet the rules, pay attention

# %%
from typing import List, dict, set, tuple
# In operator
names = List[str] = ["Nate", "Rebecca", "Edwin", "Preston"] # use | for or to give options [str|int]
choice = input(f"choose a name from the following: {', '.join(names)}")

if choice in names:
    print(f"horaay, {choice} is in names")
else:
    print("You suck. Follow instructions")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 from typing import List, dict, set, tuple
#       2 # In operator
#       3 names = List[str] = ["Nate", "Rebecca", "Edwin", "Preston"] # use | for or to give options [str|int]
#
# ImportError: cannot import name 'dict' from 'typing' (c:\Users\Maria Paz Cevallos\anaconda3\Lib\typing.py)
